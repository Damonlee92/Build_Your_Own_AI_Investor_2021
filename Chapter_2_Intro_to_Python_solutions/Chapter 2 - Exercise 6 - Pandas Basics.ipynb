# %% [markdown]
# # Exercise 6 – Pandas Basics

# %%
# Code from Book: Build Your Own AI Investor
# Damon Lee 2021
# Check out the performance on www.valueinvestingai.com
# Code uses data from the (presumably) nice people at https://simfin.com/. 
# Feel free to fork this code for others to see what can be done with it.

# %%
# Set the plotting DPI settings to be a bit higher.
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [8.0, 5.0]
plt.rcParams['figure.dpi'] = 150

# %%
#Import Pandas
import pandas as pd

# %%
#Creating a dictionary with some table data in it.
dict = {
    'Name':['Tom', 'Dick', 'Harry'],
    'Age':[24, 35, 29],
    'Shoe Size':[7,8,9]
}

# %%
#Creating a DataFrame with the data from the dictionary
df=pd.DataFrame(dict)

# %%
#The dataframe can be viewed without the print() command.
df
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %%
#Write the data from the DataFrame to a file
df.to_csv('people.csv')

# %%
# Now I want to read the data, lets create a new DataFrame. Remember to specify an index column!
my_data=pd.read_csv('people.csv', index_col=0)

# %%
#have a look at the data
my_data
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %% [markdown]
# # Read in SimFin data

# %%
# Lets read some income statement data from SimFin (https://simfin.com/)
# Your download directory will differ.
Income_Data=pd.read_csv(\
    'C:/Users/G50/Stock_Data/SimFin/us-income-annual/us-income-annual.csv',\
                        delimiter=';')

# %%
# get the DataFrame shape (Might be useful for other computation)
print('DataFrame shape is: ',Income_Data.shape)
#Have a look at what our DataFrame looks like
Income_Data
# You will notice that thefirst few and last few items are shown (Jupyter doesn't want to display all 15,124 rows.)
# Out:
# DataFrame shape is:  (17129, 28)
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0          A     45846      USD         2008            FY  2008-10-31
# 1          A     45846      USD         2009            FY  2009-10-31
# 2          A     45846      USD         2010            FY  2010-10-31
# 3          A     45846      USD         2011            FY  2011-10-31
# 4          A     45846      USD         2012            FY  2012-10-31
# ...      ...       ...      ...          ...           ...         ...
# 17124    low    186050      USD         2015            FY  2016-02-29
# 17125    low    186050      USD         2016            FY  2017-02-28
# 17126    low    186050      USD         2017            FY  2018-02-28
# 17127    low    186050      USD         2018            FY  2019-02-28
# 17128    low    186050      USD         2019            FY  2020-02-29
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2009-01-05    2010-12-20     363000000.0       371000000.0  ...
# 1       2009-12-21    2011-12-16     346000000.0       346000000.0  ...
# 2       2010-12-08    2012-12-20     347000000.0       353000000.0  ...
# 3       2011-12-16    2013-12-19     347000000.0       355000000.0  ...
# 4       2012-12-20    2014-12-22     348000000.0       353000000.0  ...
# ...            ...           ...             ...               ...  ...
# 17124   2016-03-29    2017-04-04     927000000.0       929000000.0  ...
# 17125   2017-04-04    2017-04-04     880000000.0       881000000.0  ...
# 17126   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
# 17127   2019-03-23    2020-03-23     811000000.0       812000000.0  ...
# 17128   2020-03-23    2020-03-23     777000000.0       778000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                       20000000.0            -10000000.0
# 1                      -40000000.0            -59000000.0
# 2                       -6000000.0            -76000000.0
# 3                      -39000000.0            -72000000.0
# 4                      -76000000.0            -92000000.0
# ...                            ...                    ...
# 17124                 -552000000.0           -552000000.0
# 17125                 -645000000.0           -645000000.0
# 17126                 -633000000.0           -633000000.0
# 17127                 -624000000.0           -624000000.0
# 17128                 -691000000.0           -691000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 0                       815000000                      0.0
# 1                         7000000                      0.0
# 2                       560000000              132000000.0
# 3                      1032000000                      NaN
# 4                      1043000000                      NaN
# ...                           ...                      ...
# 17124                  4419000000                      NaN
# 17125                  5201000000                      NaN
# 17126                  5953000000             -464000000.0
# 17127                  3394000000                      0.0
# 17128                  5623000000                      0.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0                 815000000                      -1.220000e+08
# 1                   7000000                      -3.800000e+07
# 2                 692000000                      -8.000000e+06
# 3                1032000000                      -2.000000e+07
# 4                1043000000                       1.100000e+08
# ...                     ...                                ...
# 17124            4419000000                      -1.873000e+09
# 17125            5201000000                      -2.108000e+09
# 17126            5489000000                      -2.042000e+09
# 17127            3394000000                      -1.080000e+09
# 17128            5623000000                      -1.342000e+09
#
#        Income (Loss) from Continuing Operations  \
# 0                                     693000000
# 1                                     -31000000
# 2                                     684000000
# 3                                    1012000000
# 4                                    1153000000
# ...                                         ...
# 17124                                2546000000
# 17125                                3093000000
# 17126                                3447000000
# 17127                                2314000000
# 17128                                4281000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                   NaN   693000000            693000000
# 1                                   NaN   -31000000            -31000000
# 2                                   NaN   684000000            684000000
# 3                                   NaN  1012000000           1012000000
# 4                                   NaN  1153000000           1153000000
# ...                                 ...         ...                  ...
# 17124                               NaN  2546000000           2546000000
# 17125                               NaN  3093000000           3093000000
# 17126                               NaN  3447000000           3447000000
# 17127                               NaN  2314000000           2314000000
# 17128                               NaN  4281000000           4281000000
#
# [17129 rows x 28 columns]

# %%
# The headings of columns are called keys. 
# The columns themselves are called series.
# To see what all the columns are in our dataframe, use the .keys() function. 
print(Income_Data.keys())
# Out:
# Index(['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period',
#        'Report Date', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')

# %%
# To see series data for a single key:
Income_Data['Ticker']
# Out:
# 0          A
# 1          A
# 2          A
# 3          A
# 4          A
#         ...
# 17124    low
# 17125    low
# 17126    low
# 17127    low
# 17128    low
# Name: Ticker, Length: 17129, dtype: object

# %%
Income_Data['Report Date']
# Out:
# 0        2008-10-31
# 1        2009-10-31
# 2        2010-10-31
# 3        2011-10-31
# 4        2012-10-31
#             ...
# 17124    2016-02-29
# 17125    2017-02-28
# 17126    2018-02-28
# 17127    2019-02-28
# 17128    2020-02-29
# Name: Report Date, Length: 17129, dtype: object

# %%
print('The resulting type of object from our series selection is a:', type(Income_Data['Report Date']) )
print('using .values after our selection turns this into a:', type(Income_Data['Report Date'].values) )
# Out:
# The resulting type of object from our series selection is a: <class 'pandas.core.series.Series'>
# using .values after our selection turns this into a: <class 'numpy.ndarray'>

# %%
# To get a list of tickers that exist, we could use the set operations we learned earlier.
my_set = set(Income_Data['Ticker'].values)
print(my_set)
# Out:
# {'ABC', 'SNA', 'CROX', 'EXA', 'VRNS', 'IMO', 'ITCI', 'CIK', 'GPS', 'LAYN', 'MSCI', 'KEM', 'TLRY', 'EMN', 'GLW', 'BLK', 'BRKS', 'LKQ', 'FTV', 'LVGO', 'LSXMA', 'BRRE', 'AMBA', 'VNCE', 'TTOO', 'ITRI', 'REZI', 'CAR', 'CLBS', 'SYY', 'BNED', 'CNNX', 'MACK', 'SPLK', 'AMED', 'TTC', 'VDSI', 'SFS', 'UFI', 'DD', 'ADSK', 'AJG', 'ASPN', 'DLTH', 'KKD', 'WINH', 'ESL', 'MTEM', 'LITE', 'BHI', 'CNVR', 'AGIO', 'HSII', 'AVA', 'JBHT', 'CHDN', 'SHLO', 'MSCC', 'NWY', 'DYN', 'DGX', 'AKER', 'MLAB', 'SCVL', 'TCNT', 'CHWY', 'UPS', 'CASY', 'TREE', 'TDOC', 'ARO', 'PPL', 'CGA', 'CY', 'SSNT', 'EXTR', 'VEEV', 'KPTI', 'TRHC', 'LSI_old', 'LBTYA', 'ADES', 'RP', 'REPR', 'ESV', 'ALXN', 'BYD', 'ALLE', 'ERS', 'HURN', 'MNK', 'LOPE', 'SRE', 'CLF', 'COO', 'ETN', 'CRWS', 'MDB', 'SPLS', 'CIEN', 'MDR', 'RMCF', 'PKE', 'WEC', 'RIHT', 'ARAY', 'CTS', 'CCS', 'RGS', 'FLS', 'LIVE', 'ADI', 'BKNG', 'MSI', 'AREX', 'MA', 'NTNX', 'FNSR', 'UFS', 'GDOT', 'EXPE', 'HXL', 'FSLR', 'LMT', 'LPX', 'RWC', 'PRTX', 'UA', 'IP', 'ATVI', 'NHTC', 'CMCSA', 'VMW', 'ASH', 'KE', 'OPHT', 'ICPT', 'VAPE', 'ABMD', 'ALE', 'PEGA', 'MEET', 'AMSWA', 'CHD', 'ATKR', 'AVT', 'ETR', 'BGNE', 'TLYS', 'NVCR', 'MN', 'APOG', 'FSS', 'NLSN', 'ATU', 'SBGI', 'VALU', 'NEO', 'CSL', 'FRGI', 'low', 'BHGE', 'IPAR', 'FAST', 'PDLI', 'FIT', 'XYL', 'ARNA', 'CHE', 'PVH', 'ELY', 'LL', 'AVGO_old', 'PACB', 'REI', 'SEIC', 'OXFD', 'FRX', 'CALA', 'BPMC', 'DK', 'WYNN', 'IRG', 'PSA', 'HIBB', 'NFX', 'CDNS', 'VIAB', 'HFC', 'UNP', 'TSRO', 'ADP', 'TEN', 'UMRX', 'GPC', 'CF', 'GENC', 'RUSHA', 'WFM', 'WR', 'TIVO', 'FMSA', 'WRK', 'ENV', 'SPCE', 'INGR', 'MAMS', 'PROM', 'HURC', 'NLS', 'BSX', 'DHX', 'BLL', 'BL', 'GILD', 'HAL', 'M', 'IDA', 'CTXS', 'IVZ', 'GXP', 'PKG', 'TDG', 'FBHS', 'URI', 'OLN', 'MIND', 'WGP', 'ABG', 'TBI', 'HPQ', 'MGNX', 'FII', 'XCRA', 'PLPC', 'ES_old', 'WSCI', 'YEXT', 'IHT', 'CRSP', 'TYPE', 'TPIC', 'STAY', 'TVPT', 'NERV', 'YELP', 'FELE', 'FCEL', 'NICK', 'MPC', 'CTIC', 'ANIK', 'ABCD', 'EXR', 'WSTL', 'FRPT', 'UOLI', 'OUT', 'MYCC', 'HD', 'BURL', 'MSFT', 'MDLZ', 'MOBL', 'MGLN', 'INT', 'TESO', 'AOBC', 'GERN', 'ZVO', 'FDS', 'THO', 'PAYX', 'BSET', 'WMAR', 'SPNC', 'FTI', 'PAYC', 'BMS', 'LVLT', 'FLEX', 'INVA', 'CATS', 'INOV', 'USFD', 'SAIC', 'VERU', 'AAMC', 'SAIA', 'ITGR', 'BXP', 'WINA', 'MIC', 'PAYS', 'BSPM', 'ED', 'MTRX', 'UBER', 'IDXX', 'BMI', 'CERN', 'HOG', 'BERY', 'TRGP', 'QCP', 'USM', 'BOOT', 'CR', 'SHAK', 'BCPC', 'KHC', 'ARQL', 'TXN', 'SYRS', 'HELE', 'ACGL', 'OLED', 'CSGP', 'QSIM', 'MTD', 'OXY', 'GMED', 'KONA', 'TAP', 'UTX', 'AMAT', 'MMEG', 'OTTR', 'PX', 'DXPE', 'KITE', 'STLD', 'BRO', 'LSYN', 'DISH', 'SAIL', 'MNI', 'KATE', 'BVSN', 'CP', 'ORLY', 'AIT', 'JBCT', 'MEDP', 'SPG', 'ODT', 'TEL', 'PEG', 'SRCL', 'RLGY', 'BCR', 'RCII', 'PKI', 'AXTA', 'APU', 'ECL', 'IMDZ', 'CENT', 'ZIOP', 'HLF', 'RST', 'STML', 'BR', 'SWKS', 'MATX', 'PETM', 'STX', 'ATRO', 'BLOX', 'KAR', 'PYPL', 'ZEDG', 'CCF', 'CPST', 'OVV', 'MGEE', 'RIGL', 'RNG', 'REMI', 'GRMN', 'RAIL', 'GUID', 'SERV', 'EVA', 'YGYI', 'ARCB', 'CSU', 'FISV', 'USAP', 'MJN', 'SRNE', 'GCO', 'ALK', 'CQH', 'TPR', 'TROX', 'IFON', 'DTE', 'FLT', 'MRAM', 'GPRE', 'GWRE', 'ALR', 'CBI', 'AMOT', 'DPZ', 'EVLO', 'LEVI', 'CSLT', 'XOM', 'COTV', 'SPGI', 'LFUS', 'HPJ', 'ZAYO', 'CMC', 'MENT', 'OHI', 'Golf', 'BJRI', 'IT', 'WU', 'CLNE', 'CHEF', 'NVAX', 'TRNX', 'BBSI', 'LPLA', 'LC', 'ESI', 'DKS', 'LYB', 'SYNA', 'MTBC', 'LULU', 'TENB', 'CCK', 'KMG', 'DYNT', 'STRT', 'OKE', 'WYND', 'SOLY', 'AMZN', 'CPT', 'CST', 'FGP', 'O', 'IVTY', 'MMP', 'FTR', 'PCG', 'TSSI', 'MDSO', 'SCOR', 'GLGI', 'PGTI', 'PEP', 'SPB', 'MASI', 'TNDM', 'COR', 'ADNT', 'ASTC', 'AEP', 'NEOS', 'XONE', 'MMI', 'INTL', 'CELG', 'EVRI', 'TA', 'G', 'BREW', 'MGCD', 'GSEG', 'JCS', 'FLXS', 'CBG', 'CBLK', 'AGR', 'ALCO', 'SGA', 'CLC', 'TRIP', 'HTM', 'ODP', 'CETX', 'SUPN', 'USG', 'GBX', 'MYL', 'TNET', 'NOW', 'COLM', 'H', 'HEAR', 'PDFS', 'DISCA', 'AMH', 'CASI', 'ES', 'STE', 'XRX', 'ACCO', 'AC', 'HAYN', 'MVIS', 'REV', 'SYNT', 'VGR', 'BAH', 'AMSC', 'SMCI', 'BKI', 'NEPH', 'TBIO', 'PRPL', 'HSIC', 'WEB', 'IRBT', 'EMC', 'BFB', 'JOY', 'FONR', 'SKY', 'AYX', 'CVCO', 'KANP', 'PJT', 'P ...

# %%
#Alternatively a dataframe has a function .unique()
Income_Data['Ticker'].unique()
# Out:
# array(['A', 'AA', 'AAC', ..., 'ZYNE', 'ZYXI', 'low'], dtype=object)

# %%
# You can use logic on dataframes to obtain a list of boolean values that say whether a rule is True or False for each row.
# Let's try and isolate financial data for the 2017 fiscal period. 
# We will do a boolean check on items in the 'Fiscal Year' column:

IsIt2017 = (Income_Data['Fiscal Year'] == 2017)
print('The boolean logic on the Fiscal Year column is: ', IsIt2017)
# Out:
# The boolean logic on the Fiscal Year column is:  0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17124    False
# 17125    False
# 17126     True
# 17127    False
# 17128    False
# Name: Fiscal Year, Length: 17129, dtype: bool

# %%
# We can use this list of booleans to make a smaller dataframe with only data from fiscal year 2017 as follows:
Income_Data[IsIt2017]
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9          A     45846      USD         2017            FY  2017-10-31
# 14        AA    367153      USD         2017            FY  2017-12-31
# 26       AAL     68568      USD         2017            FY  2017-12-31
# 33      AAMC    847094      USD         2017            FY  2017-12-31
# 44       AAN    441241      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 17088   ZUMZ     45730      USD         2017            FY  2018-02-28
# 17098    ZVO    901866      USD         2017            FY  2017-12-31
# 17104   ZYNE    901704      USD         2017            FY  2017-12-31
# 17114   ZYXI    171401      USD         2017            FY  2017-12-31
# 17126    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 9       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 14      2018-02-26    2018-02-26     184000000.0       187000000.0  ...
# 26      2018-02-21    2018-02-21     489164000.0       491692000.0  ...
# 33      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 44      2018-03-01    2018-03-01      70837000.0        72121000.0  ...
# ...            ...           ...             ...               ...  ...
# 17088   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 17098   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 17104   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 17114   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
# 17126   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                      -38000000.0            -57000000.0
# 14                     -46000000.0           -104000000.0
# 26                    -974000000.0           -959000000.0
# 33                       1086000.0                    0.0
# 44                     -15122000.0            -18703000.0
# ...                            ...                    ...
# 17088                    -357000.0               495000.0
# 17098                    1511000.0                    NaN
# 17104                     810705.0               519554.0
# 17114                   -1450000.0             -1450000.0
# 17126                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 9                       803000000                      NaN
# 14                     1468000000             -309000000.0
# 26                     3084000000                      NaN
# 33                       -6261000                      0.0
# 44                      257571000              -17994000.0
# ...                           ...                      ...
# 17088                    48403000                      NaN
# 17098                    16619000               -8682000.0
# 17104                   -32012304                      0.0
# 17114                     7494000                      NaN
# 17126                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 9                 803000000                      -1.190000e+08
# 14               1159000000                      -6.000000e+08
# 26               3084000000                      -1.165000e+09
# 33                 -6261000                      -7.080000e+05
# 44                239577000                       5.295900e+07
# ...                     ...                                ...
# 17088              48403000                      -2.160100e+07
# 17098               7937000                       1.174000e+06
# 17104             -32012304                       0.000000e+00
# 17114               7494000                      -1.290000e+05
# 17126            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 9                                     684000000
# 14                                    559000000
# 26                                   1919000000
# 33                                     -6969000
# 44                                    292536000
# ...                                         ...
# 17088                                  26802000
# 17098                                   9111000
# 17104                                 -32012304
# 17114                                   7365000
# 17126                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                   NaN   684000000            684000000
# 14                                  NaN   217000000            217000000
# 26                                  NaN  1919000000           1919000000
# 33                                  NaN    -6969000             -7175000
# 44                                  NaN   292536000            292536000
# ...                                 ...         ...                  ...
# 17088                               NaN    26802000             26802000
# 17098                               NaN     9111000              9111000
# 17104                               NaN   -32012304            -32012304
# 17114                               NaN     7365000              7365000
# 17126                               NaN  3447000000           3447000000
#
# [1780 rows x 28 columns]

# %%
# Or if we want to do this kind of filter in a single line:
Income_Data[Income_Data['Fiscal Year'] == 2017]
#Which is basically: 'I want the rows of Income_Data where the Income_Data Fiscal Year column is 2017.'
# Notice there are only 1,726 rows instead of 15,125
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9          A     45846      USD         2017            FY  2017-10-31
# 14        AA    367153      USD         2017            FY  2017-12-31
# 26       AAL     68568      USD         2017            FY  2017-12-31
# 33      AAMC    847094      USD         2017            FY  2017-12-31
# 44       AAN    441241      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 17088   ZUMZ     45730      USD         2017            FY  2018-02-28
# 17098    ZVO    901866      USD         2017            FY  2017-12-31
# 17104   ZYNE    901704      USD         2017            FY  2017-12-31
# 17114   ZYXI    171401      USD         2017            FY  2017-12-31
# 17126    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 9       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 14      2018-02-26    2018-02-26     184000000.0       187000000.0  ...
# 26      2018-02-21    2018-02-21     489164000.0       491692000.0  ...
# 33      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 44      2018-03-01    2018-03-01      70837000.0        72121000.0  ...
# ...            ...           ...             ...               ...  ...
# 17088   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 17098   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 17104   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 17114   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
# 17126   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                      -38000000.0            -57000000.0
# 14                     -46000000.0           -104000000.0
# 26                    -974000000.0           -959000000.0
# 33                       1086000.0                    0.0
# 44                     -15122000.0            -18703000.0
# ...                            ...                    ...
# 17088                    -357000.0               495000.0
# 17098                    1511000.0                    NaN
# 17104                     810705.0               519554.0
# 17114                   -1450000.0             -1450000.0
# 17126                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 9                       803000000                      NaN
# 14                     1468000000             -309000000.0
# 26                     3084000000                      NaN
# 33                       -6261000                      0.0
# 44                      257571000              -17994000.0
# ...                           ...                      ...
# 17088                    48403000                      NaN
# 17098                    16619000               -8682000.0
# 17104                   -32012304                      0.0
# 17114                     7494000                      NaN
# 17126                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 9                 803000000                      -1.190000e+08
# 14               1159000000                      -6.000000e+08
# 26               3084000000                      -1.165000e+09
# 33                 -6261000                      -7.080000e+05
# 44                239577000                       5.295900e+07
# ...                     ...                                ...
# 17088              48403000                      -2.160100e+07
# 17098               7937000                       1.174000e+06
# 17104             -32012304                       0.000000e+00
# 17114               7494000                      -1.290000e+05
# 17126            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 9                                     684000000
# 14                                    559000000
# 26                                   1919000000
# 33                                     -6969000
# 44                                    292536000
# ...                                         ...
# 17088                                  26802000
# 17098                                   9111000
# 17104                                 -32012304
# 17114                                   7365000
# 17126                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                   NaN   684000000            684000000
# 14                                  NaN   217000000            217000000
# 26                                  NaN  1919000000           1919000000
# 33                                  NaN    -6969000             -7175000
# 44                                  NaN   292536000            292536000
# ...                                 ...         ...                  ...
# 17088                               NaN    26802000             26802000
# 17098                               NaN     9111000              9111000
# 17104                               NaN   -32012304            -32012304
# 17114                               NaN     7365000              7365000
# 17126                               NaN  3447000000           3447000000
#
# [1780 rows x 28 columns]

# %%
# Let's order the stocks for financial year 2017 by net income.
# Within a DataFrame the rows can be ordered as follows:
Income_Data.sort_values(by=['Net Income'])
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 6517      GE    244314      USD         2018            FY  2018-12-31
# 3769     COP    378120      USD         2008            FY  2008-12-31
# 14787   TEVA    616649      USD         2017            FY  2017-12-31
# 5761       F    249937      USD         2008            FY  2008-12-31
# 3261     CHK    378111      USD         2015            FY  2015-12-31
# ...      ...       ...      ...          ...           ...         ...
# 85      AAPL    111052      USD         2017            FY  2017-09-30
# 83      AAPL    111052      USD         2015            FY  2015-09-30
# 87      AAPL    111052      USD         2019            FY  2019-09-30
# 86      AAPL    111052      USD         2018            FY  2018-09-30
# 2520    BRKA     71306      USD         2019            FY  2019-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 6517    2019-02-26    2019-02-26    8.691000e+09      8.691000e+09  ...
# 3769    2009-02-03    2011-02-23    1.523432e+09      1.523432e+09  ...
# 14787   2018-02-01    2019-02-19    1.016000e+09      1.016000e+09  ...
# 5761    2009-02-05    2011-02-28    2.273000e+09      2.272000e+09  ...
# 3261    2016-02-04    2018-02-22    3.310000e+06      3.310000e+06  ...
# ...            ...           ...             ...               ...  ...
# 85      2017-11-02    2018-11-05    5.217242e+09      5.251692e+09  ...
# 83      2015-10-28    2017-11-03    5.753421e+09      5.793069e+09  ...
# 87      2019-10-31    2019-10-31    4.617834e+09      4.648913e+09  ...
# 86      2018-11-05    2018-11-05    4.955377e+09      5.000109e+09  ...
# 2520    2020-02-24    2020-02-24    3.268661e+06      3.268661e+06  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 6517                 -5.590000e+09          -5.059000e+09
# 3769                  4.263000e+09          -9.350000e+08
# 14787                 3.040000e+08          -8.950000e+08
# 5761                 -8.920000e+09          -9.737000e+09
# 3261                 -4.050000e+08          -3.170000e+08
# ...                            ...                    ...
# 85                    2.745000e+09                    NaN
# 83                    1.285000e+09                    NaN
# 87                    1.807000e+09                    NaN
# 86                    2.005000e+09                    NaN
# 2520                  4.187300e+10                    NaN
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 6517                   4779000000            -2.491300e+10
# 3769                  31409000000            -3.426900e+10
# 14787                  4295000000            -2.267400e+10
# 5761                 -14895000000                      NaN
# 3261                   -852000000            -1.824600e+10
# ...                           ...                      ...
# 85                    64089000000                      NaN
# 83                    72515000000                      NaN
# 87                    65737000000                      NaN
# 86                    72903000000                      NaN
# 2520                 101520000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 6517           -20134000000                      -5.830000e+08
# 3769            -2860000000                      -1.341900e+10
# 14787          -18379000000                       1.933000e+09
# 5761           -14895000000                       6.200000e+07
# 3261           -19098000000                       4.463000e+09
# ...                     ...                                ...
# 85              64089000000                      -1.573800e+10
# 83              72515000000                      -1.912100e+10
# 87              65737000000                      -1.048100e+10
# 86              72903000000                      -1.337200e+10
# 2520           101520000000                      -2.090400e+10
#
#        Income (Loss) from Continuing Operations  \
# 6517                               -20717000000
# 3769                               -16279000000
# 14787                              -16449000000
# 5761                               -14833000000
# 3261                               -14635000000
# ...                                         ...
# 85                                  48351000000
# 83                                  53394000000
# 87                                  55256000000
# 86                                  59531000000
# 2520                                81792000000
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 6517                      -1.726000e+09 -22354000000         -22801000000
# 3769                                NaN -16349000000         -16349000000
# 14787                               NaN -16265000000         -16525000000
# 5761                       9.000000e+06 -14766000000         -14766000000
# 3261                                NaN -14567000000         -14738000000
# ...                                 ...          ...                  ...
# 85                                  NaN  48351000000          48351000000
# 83                                  NaN  53394000000          53394000000
# 87                                  NaN  55256000000          55256000000
# 86                                  NaN  59531000000          59531000000
# 2520                                NaN  81417000000          81417000000
#
# [17129 rows x 28 columns]

# %%
# However, we wish to perform this for only the 2017 fiscal year. 
# Fortunately you can just put one operations in front of the other as follows:
Income_Data[Income_Data['Fiscal Year'] == 2017].sort_values(by=['Net Income'])
# It looks like AAPL and BRKA earned the most money that year, more than $40bn!
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 14787   TEVA    616649      USD         2017            FY  2017-12-31
# 6516      GE    244314      USD         2017            FY  2017-12-31
# 10296    MRO    378185      USD         2017            FY  2017-12-31
# 562      AGN     61474      USD         2017            FY  2017-12-31
# 6727      GM    125620      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 10356   MSFT     59265      USD         2017            FY  2017-06-30
# 14613      T     66790      USD         2017            FY  2017-12-31
# 16227     VZ    101219      USD         2017            FY  2017-12-31
# 2518    BRKA     71306      USD         2017            FY  2017-12-31
# 85      AAPL    111052      USD         2017            FY  2017-09-30
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 14787   2018-02-01    2019-02-19    1.016000e+09      1.016000e+09  ...
# 6516    2018-02-23    2018-02-23    8.687000e+09      8.687000e+09  ...
# 10296   2018-02-22    2018-02-22    8.500000e+08      8.500000e+08  ...
# 562     2018-02-16    2018-02-16    3.338000e+08      3.338000e+08  ...
# 6727    2018-02-06    2018-02-06    1.465000e+09      1.492000e+09  ...
# ...            ...           ...             ...               ...  ...
# 10356   2017-07-27    2018-08-03    7.746000e+09      7.832000e+09  ...
# 14613   2018-02-20    2019-02-20    6.164000e+09      6.183000e+09  ...
# 16227   2018-02-23    2018-02-23    4.084000e+09      4.089000e+09  ...
# 2518    2018-02-26    2018-02-26    3.289647e+06      3.289647e+06  ...
# 85      2017-11-02    2018-11-05    5.217242e+09      5.251692e+09  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 14787                 3.040000e+08          -8.950000e+08
# 6516                 -1.703700e+10          -4.869000e+09
# 10296                -2.700000e+08          -2.700000e+08
# 562                  -4.465200e+09          -1.027900e+09
# 6727                  1.847000e+09          -5.750000e+08
# ...                            ...                    ...
# 10356                 8.760000e+08                    NaN
# 14613                -4.703000e+09          -6.300000e+09
# 16227                -6.820000e+09          -4.733000e+09
# 2518                           NaN                    NaN
# 85                    2.745000e+09                    NaN
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 14787                  4295000000            -2.267400e+10
# 6516                  -8791000000                      NaN
# 10296                  -174000000            -2.800000e+08
# 562                  -10386400000                      NaN
# 6727                  11863000000             0.000000e+00
# ...                           ...                      ...
# 10356                 30207000000            -3.060000e+08
# 14613                 18181000000            -2.914000e+09
# 16227                 20594000000                      NaN
# 2518                  20900000000                      NaN
# 85                    64089000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 14787          -18379000000                       1.933000e+09
# 6516            -8791000000                       3.043000e+09
# 10296            -454000000                      -3.760000e+08
# 562            -10386400000                       6.670400e+09
# 6727            11863000000                      -1.153300e+10
# ...                     ...                                ...
# 10356           29901000000                      -4.412000e+09
# 14613           15267000000                       1.470800e+10
# 16227           20594000000                       9.956000e+09
# 2518            20900000000                       2.151500e+10
# 85              64089000000                      -1.573800e+10
#
#        Income (Loss) from Continuing Operations  \
# 14787                              -16449000000
# 6516                                -5748000000
# 10296                                -830000000
# 562                                 -3716000000
# 6727                                  330000000
# ...                                         ...
# 10356                               25489000000
# 14613                               29847000000
# 16227                               30550000000
# 2518                                45353000000
# 85                                  48351000000
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 14787                               NaN -16265000000         -16525000000
# 6516                      -3.090000e+08  -5787000000          -6223000000
# 10296                     -4.893000e+09  -5723000000          -5723000000
# 562                       -4.029000e+08  -4125500000          -4403900000
# 6727                      -4.212000e+09  -3864000000          -3880000000
# ...                                 ...          ...                  ...
# 10356                               NaN  25489000000          25489000000
# 14613                               NaN  29450000000          29450000000
# 16227                               NaN  30101000000          30101000000
# 2518                                NaN  44940000000          44940000000
# 85                                  NaN  48351000000          48351000000
#
# [1780 rows x 28 columns]

# %%
# Lets plot the distribution of net income for all american companies:
Income_Data['Net Income'].hist()
# Out:
# <AxesSubplot:>

# %%
# Plot graph with just 2017 FY data, logarithmic Y axis and more bins for greater resolution.
from matplotlib import pyplot as plt # Import plotting library
Income_Data[Income_Data['Fiscal Year'] == 2017]['Net Income'].hist(bins=100, log=True)
plt.title('USA Corporate Net Income for 2017 Histogram')
plt.xlabel('Value in USD')
plt.ylabel('Number of Instances')
print('Max value is: ', Income_Data[Income_Data['Fiscal Year'] == 2017]['Net Income'].max())
# Out:
# Max value is:  48351000000

# %%
# Statistical data can be calculated with the dataframe .describe() function
Income_Data.describe()
# Out:
#             SimFinId   Fiscal Year  Shares (Basic)  Shares (Diluted)  \
# count   17129.000000  17129.000000    1.701800e+04      1.701800e+04
# mean   413064.400782   2014.407905    2.354918e+08      2.398169e+08
# std    275023.871212      3.022925    6.509797e+08      6.650934e+08
# min        18.000000   2007.000000    3.700000e+01      3.700000e+01
# 25%    169714.000000   2012.000000    2.696775e+07      2.731600e+07
# 50%    378111.000000   2015.000000    6.620768e+07      6.732950e+07
# 75%    652365.000000   2017.000000    1.886207e+08      1.914318e+08
# max    993675.000000   2020.000000    1.066100e+10      1.067800e+10
#
#             Revenue  Cost of Revenue  Gross Profit  Operating Expenses  \
# count  1.684100e+04     1.557400e+04  1.685600e+04        1.704900e+04
# mean   7.481832e+09    -5.224883e+09  2.648404e+09       -1.681331e+09
# std    2.469681e+10     1.877478e+10  8.084087e+09        5.050896e+09
# min    0.000000e+00    -3.946050e+11 -1.280800e+10       -1.087910e+11
# 25%    2.839920e+08    -3.100996e+09  1.200918e+08       -1.225803e+09
# 50%    1.425395e+09    -7.958500e+08  5.702680e+08       -3.675850e+08
# 75%    5.190000e+09    -1.457800e+08  1.970400e+09       -9.270000e+07
# max    5.239640e+11     3.100000e+07  1.722200e+11        1.110132e+09
#
#        Selling, General & Administrative  Research & Development  ...  \
# count                       1.628600e+04            6.812000e+03  ...
# mean                       -1.143160e+09           -4.013717e+08  ...
# std                         4.025915e+09            1.323563e+09  ...
# min                        -1.087910e+11           -2.601800e+10  ...
# 25%                        -8.088830e+08           -1.892340e+08  ...
# 50%                        -2.115150e+08           -5.372050e+07  ...
# 75%                        -4.799025e+07           -1.443925e+07  ...
# max                         0.000000e+00            6.480000e+05  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# count                 1.697800e+04           1.514400e+04
# mean                 -1.232958e+08          -1.348186e+08
# std                   1.346241e+09           4.793649e+08
# min                  -5.912000e+10          -2.575800e+10
# 25%                  -8.533300e+07          -1.110358e+08
# 50%                  -1.110000e+07          -2.268100e+07
# 75%                  -4.100000e+04          -9.127698e+05
# max                   4.187300e+10           1.537000e+09
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# count                1.712900e+04             1.133900e+04
# mean                 8.109714e+08            -1.352606e+08
# std                  3.204352e+09             9.846223e+08
# min                 -1.489500e+10            -3.426900e+10
# 25%                  8.650000e+05            -4.500000e+07
# 50%                  1.003120e+08            -4.471000e+06
# 75%                  5.156530e+08             0.000000e+00
# max                  1.015200e+11             1.289400e+10
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# count          1.712900e+04                       1.613200e+04
# mean           7.214320e+08                      -1.967143e+08
# std            3.202980e+09                       1.097688e+09
# min           -2.869500e+10                      -3.653000e+10
# 25%           -1.315979e+06                      -1.261730e+08
# 50%            8.128300e+07                      -2.055800e+07
# 75%            4.680000e+08                      -3.170000e+05
# max            1.015200e+11                       3.483100e+10
#
#        Income (Loss) from Continuing Operations  \
# count                              1.712900e+04
# mean                               5.383015e+08
# std                                2.416212e+09
# min                               -2.071700e+10
# 25%                               -1.579000e+06
# 50%                                6.057800e+07
# 75%                                3.538230e+08
# max                                8.179200e+10
#
#        Net Extraordinary Gains (Losses)    Net Income  Net Income (Common)
# count                      3.655000e+03  1.712900e+04         1.712900e+04
# mean                       4.870889e+07  5.323545e+08         5.295753e+08
# std                        6.350838e+08  2.406332e+09         2.405082e+09
# min                       -9.559000e+09 -2.235400e+10        -2.280100e+10
# 25%                       -3.792500e+06 -1.705000e+06        -2.018000e+06
# 50%                        0.000000e+00  5.896400e+07         5.820800e+07
# 75%                        1.454000e+07  3.527900e+08         3.501040e+08
# max                        1.591450e+10  8.141700e+10         8.141700e+10
#
# [8 rows x 22 columns]

# %%
# You can create new dataframes from filtered old dataframes, let's separate the 2017 fiscal year data to a new dataframe.
Income_Data_2017 = Income_Data[Income_Data['Fiscal Year'] == 2017]

# %%
Income_Data_2017.head(9)
# Out:
#    Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9       A     45846      USD         2017            FY  2017-10-31
# 14     AA    367153      USD         2017            FY  2017-12-31
# 26    AAL     68568      USD         2017            FY  2017-12-31
# 33   AAMC    847094      USD         2017            FY  2017-12-31
# 44    AAN    441241      USD         2017            FY  2017-12-31
# 52   AAOI    671827      USD         2017            FY  2017-12-31
# 62   AAON    919501      USD         2017            FY  2017-12-31
# 73    AAP    184955      USD         2017            FY  2017-12-31
# 85   AAPL    111052      USD         2017            FY  2017-09-30
#
#    Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 9    2017-12-21    2018-12-20    3.220000e+08      3.260000e+08  ...
# 14   2018-02-26    2018-02-26    1.840000e+08      1.870000e+08  ...
# 26   2018-02-21    2018-02-21    4.891640e+08      4.916920e+08  ...
# 33   2018-03-01    2018-03-01    1.570428e+06      1.570428e+06  ...
# 44   2018-03-01    2018-03-01    7.083700e+07      7.212100e+07  ...
# 52   2018-02-28    2018-02-28    1.909736e+07      2.013910e+07  ...
# 62   2018-02-27    2019-02-28    5.257250e+07      5.307873e+07  ...
# 73   2018-02-21    2018-02-21    7.384600e+07      7.411000e+07  ...
# 85   2017-11-02    2018-11-05    5.217242e+09      5.251692e+09  ...
#
#     Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                 -3.800000e+07            -57000000.0
# 14                -4.600000e+07           -104000000.0
# 26                -9.740000e+08           -959000000.0
# 33                 1.086000e+06                    0.0
# 44                -1.512200e+07            -18703000.0
# 52                -2.425000e+06              -637000.0
# 62                 3.890000e+05               298000.0
# 73                -4.995300e+07            -58801000.0
# 85                 2.745000e+09                    NaN
#
#     Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 9                    803000000                      NaN             803000000
# 14                  1468000000             -309000000.0            1159000000
# 26                  3084000000                      NaN            3084000000
# 33                    -6261000                      0.0              -6261000
# 44                   257571000              -17994000.0             239577000
# 52                    84526000                      NaN              84526000
# 62                    74537000                 -45000.0              74492000
# 73                   520259000                      NaN             520259000
# 85                 64089000000                      NaN           64089000000
#
#     Income Tax (Expense) Benefit, Net  \
# 9                       -1.190000e+08
# 14                      -6.000000e+08
# 26                      -1.165000e+09
# 33                      -7.080000e+05
# 44                       5.295900e+07
# 52                      -1.057500e+07
# 62                      -1.999400e+07
# 73                      -4.475400e+07
# 85                      -1.573800e+10
#
#     Income (Loss) from Continuing Operations  \
# 9                                  684000000
# 14                                 559000000
# 26                                1919000000
# 33                                  -6969000
# 44                                 292536000
# 52                                  73951000
# 62                                  54498000
# 73                                 475505000
# 85                               48351000000
#
#     Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 9                                NaN    684000000            684000000
# 14                               NaN    217000000            217000000
# 26                               NaN   1919000000           1919000000
# 33                               NaN     -6969000             -7175000
# 44                               NaN    292536000            292536000
# 52                               NaN     73951000             73951000
# 62                               NaN     54498000             54498000
# 73                               NaN    475505000            475505000
# 85                               NaN  48351000000          48351000000
#
# [9 rows x 28 columns]

# %%
Income_Data_2017.tail()
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 17088   ZUMZ     45730      USD         2017            FY  2018-02-28
# 17098    ZVO    901866      USD         2017            FY  2017-12-31
# 17104   ZYNE    901704      USD         2017            FY  2017-12-31
# 17114   ZYXI    171401      USD         2017            FY  2017-12-31
# 17126    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 17088   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 17098   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 17104   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 17114   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
# 17126   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 17088                    -357000.0               495000.0
# 17098                    1511000.0                    NaN
# 17104                     810705.0               519554.0
# 17114                   -1450000.0             -1450000.0
# 17126                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 17088                    48403000                      NaN
# 17098                    16619000               -8682000.0
# 17104                   -32012304                      0.0
# 17114                     7494000                      NaN
# 17126                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 17088              48403000                      -2.160100e+07
# 17098               7937000                       1.174000e+06
# 17104             -32012304                       0.000000e+00
# 17114               7494000                      -1.290000e+05
# 17126            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 17088                                  26802000
# 17098                                   9111000
# 17104                                 -32012304
# 17114                                   7365000
# 17126                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 17088                               NaN    26802000             26802000
# 17098                               NaN     9111000              9111000
# 17104                               NaN   -32012304            -32012304
# 17114                               NaN     7365000              7365000
# 17126                               NaN  3447000000           3447000000
#
# [5 rows x 28 columns]

# %% [markdown]
# # Exercise 6 - Rudimentary stock filtering with Pandas
# ## Objectives:
# * To take the income statement data and the stock price data to make a rudimentary stock screener for price/earnings, price sales ratios, etc.
# * To view some agregate financial data visually to gain some intuition about the corporations in the stock market.
# * To practice what has been learnt so far in meeting the objectives
#
# ### Some bits of the code are missing, follow through and try and get it working

# %% [markdown]
# ### First lets get the stock data

# %%
#get csv data from simfin.com
import pandas as pd
Income_Data = pd.read_csv('C:/Users/G50/Stock_Data/SimFin/us-income-annual/us-income-annual.csv', delimiter=';')
stock_prices = pd.read_csv('C:/Users/G50/Stock_Data/SimFin/us-shareprices-daily/us-shareprices-daily.csv', delimiter=';')

# %%
# How big are these dataframes? How is the data stored? 
# print out the shape of both dataframes

print('Income data size is: ', Income_Data.shape)
print('stock_prices data size is: ', stock_prices.shape)
# Out:
# Income data size is:  (17129, 28)
# stock_prices data size is:  (6194635, 11)

# %%
#print out the keys of the dataframes (which are the column headers)

print('Income keys are: ', Income_Data.keys())
print('stock_prices keys are: ', stock_prices.keys())
# Out:
# Income keys are:  Index(['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period',
#        'Report Date', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')
# stock_prices keys are:  Index(['Ticker', 'SimFinId', 'Date', 'Open', 'Low', 'High', 'Close',
#        'Adj. Close', 'Dividend', 'Volume', 'Shares Outstanding'],
#       dtype='object')

# %%
#Display the first 5 rows of the dataframes

Income_Data.head(5)
# Out:
#   Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0      A     45846      USD         2008            FY  2008-10-31
# 1      A     45846      USD         2009            FY  2009-10-31
# 2      A     45846      USD         2010            FY  2010-10-31
# 3      A     45846      USD         2011            FY  2011-10-31
# 4      A     45846      USD         2012            FY  2012-10-31
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0   2009-01-05    2010-12-20     363000000.0       371000000.0  ...
# 1   2009-12-21    2011-12-16     346000000.0       346000000.0  ...
# 2   2010-12-08    2012-12-20     347000000.0       353000000.0  ...
# 3   2011-12-16    2013-12-19     347000000.0       355000000.0  ...
# 4   2012-12-20    2014-12-22     348000000.0       353000000.0  ...
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                   20000000.0            -10000000.0
# 1                  -40000000.0            -59000000.0
# 2                   -6000000.0            -76000000.0
# 3                  -39000000.0            -72000000.0
# 4                  -76000000.0            -92000000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                   815000000                      0.0             815000000
# 1                     7000000                      0.0               7000000
# 2                   560000000              132000000.0             692000000
# 3                  1032000000                      NaN            1032000000
# 4                  1043000000                      NaN            1043000000
#
#    Income Tax (Expense) Benefit, Net  \
# 0                       -122000000.0
# 1                        -38000000.0
# 2                         -8000000.0
# 3                        -20000000.0
# 4                        110000000.0
#
#    Income (Loss) from Continuing Operations  Net Extraordinary Gains (Losses)  \
# 0                                 693000000                               NaN
# 1                                 -31000000                               NaN
# 2                                 684000000                               NaN
# 3                                1012000000                               NaN
# 4                                1153000000                               NaN
#
#    Net Income  Net Income (Common)
# 0   693000000            693000000
# 1   -31000000            -31000000
# 2   684000000            684000000
# 3  1012000000           1012000000
# 4  1153000000           1153000000
#
# [5 rows x 28 columns]

# %%
stock_prices.head(5)
# Out:
#   Ticker  SimFinId        Date    Open     Low    High   Close  Adj. Close  \
# 0   GOOG        18  2014-03-27  568.00  552.92  568.00  558.46      558.46
# 1   GOOG        18  2014-03-28  561.20  558.67  566.43  559.99      559.99
# 2   GOOG        18  2014-03-31  566.89  556.93  567.00  556.97      556.97
# 3   GOOG        18  2014-04-01  558.71  558.71  568.45  567.16      567.16
# 4   GOOG        18  2014-04-02  565.11  562.19  604.83  567.00      567.00
#
#    Dividend  Volume  Shares Outstanding
# 0       NaN   13100         336050831.0
# 1       NaN   41100         336050831.0
# 2       NaN   10800         674462000.0
# 3       NaN    7900         674462000.0
# 4       NaN  146700         674462000.0

# %% [markdown]
# ### Make a Market Cap series
# A lot of useful ratios commonly used to analyse companies depend on the Market Capitalization of the company, so we will add this to our dataframe first.
#
# Create a new dataframe which has all the income data as well as a market cap value, which will be the number of shares outstanding multiplied by the stock price.
#
# We will take the stock price at a relevant time for the income statement data, which should be around or just after the fiscal year reporting date.
#
# We will be using a previous fiscal year data for this exercise, where the 'Fiscal Year' series is 2017.

# %%
# See when the reporting data is usually made.
# To view a date in the series as a date object, instead of merely a string, use the pd.to_datetime() function.

# This date data has to be formatted this way for easy histogram plotting.
Income_Data['Publish Date']=pd.to_datetime(Income_Data['Publish Date'])

# Plot a histogram with a large number of bins to get a rough idea of when most reporting is done.
Income_Data[Income_Data['Fiscal Year'] == 2017]['Publish Date'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
# Make a new dataframe of only the income data from 'Fiscal Year' == 2017.
Income_Data_2018 = Income_Data[Income_Data['Fiscal Year'] == 2017]

# %%
# View the series of company tickers that exist for that fiscal year, and see how long the list is.
(Income_Data[Income_Data['Fiscal Year'] == 2017]['Ticker']).unique
# Out:
# <bound method Series.unique of 9           A
# 14         AA
# 26        AAL
# 33       AAMC
# 44        AAN
#          ...
# 17088    ZUMZ
# 17098     ZVO
# 17104    ZYNE
# 17114    ZYXI
# 17126     low
# Name: Ticker, Length: 1780, dtype: object>

# %%
# It appears as though most reporting is done just after the beginning of the year for these companies.
# Filter the stock price dataframe for the first of March of that year and make a new dataframe of that data. 
# print out the shape of the new dataframe. and use .head() to see it.

stock_prices_2018 = (stock_prices[stock_prices['Date'] == '2018-03-01'])
print('stock_prices_2018 dataframe shape is: ', stock_prices_2018.shape)
stock_prices_2018.head()
# Out:
# stock_prices_2018 dataframe shape is:  (2013, 11)
#       Ticker  SimFinId        Date     Open      Low     High    Close  \
# 989     GOOG        18  2018-03-01  1107.87  1067.00  1110.12  1069.52
# 4937    ATVI       243  2018-03-01    73.16    71.52    73.42    72.01
# 8445     BLK       914  2018-03-01   548.60   527.03   549.02   535.58
# 11953   ADBE     14099  2018-03-01   210.32   204.45   210.68   206.03
# 15461    MMM     22219  2018-03-01   236.15   229.53   236.83   231.34
#
#        Adj. Close  Dividend   Volume  Shares Outstanding
# 989       1069.52       NaN  2515910         695297530.0
# 4937        70.61       NaN  8123915         758631663.0
# 8445       494.41       NaN   779735         160718719.0
# 11953      206.03       NaN  2632234         491578529.0
# 15461      211.32       NaN  3487126         595500000.0

# %%
# Notice the size of the list of tickersin the Income statement dataframe(1726) differs from the share prices dataframe(1901)
# In the real work we frequently deal with imperfect data. We will now cut down the data to make both dataframes correspond
# so that we can add out market cap column.

# %%
# Use the .isin() dataframe function to first cut down the share prices dataframe to only contain stocks that are in the 
# Income statement dataframe.
stock_prices_2018 = stock_prices_2018[stock_prices_2018['Ticker'].isin(Income_Data_2018['Ticker'])]

# See the DataFrame
stock_prices_2018
# Out:
#         Ticker  SimFinId        Date     Open      Low     High    Close  \
# 989       GOOG        18  2018-03-01  1107.87  1067.00  1110.12  1069.52
# 4937      ATVI       243  2018-03-01    73.16    71.52    73.42    72.01
# 8445       BLK       914  2018-03-01   548.60   527.03   549.02   535.58
# 11953     ADBE     14099  2018-03-01   210.32   204.45   210.68   206.03
# 15461      MMM     22219  2018-03-01   236.15   229.53   236.83   231.34
# ...        ...       ...         ...      ...      ...      ...      ...
# 6075688   TREX    991604  2018-03-01    25.81    25.37    26.22    25.96
# 6079196    SON    992009  2018-03-01    47.91    47.19    48.15    47.44
# 6082704    CRS    993068  2018-03-01    51.21    50.74    52.33    51.27
# 6089720    HZO    993630  2018-03-01    20.90    20.15    20.90    20.45
# 6093228    ETH    993675  2018-03-01    23.75    23.55    24.30    23.95
#
#          Adj. Close  Dividend   Volume  Shares Outstanding
# 989         1069.52       NaN  2515910         695297530.0
# 4937          70.61       NaN  8123915         758631663.0
# 8445         494.41       NaN   779735         160718719.0
# 11953        206.03       NaN  2632234         491578529.0
# 15461        211.32       NaN  3487126         595500000.0
# ...             ...       ...      ...                 ...
# 6075688       25.96       NaN   372754         117714220.0
# 6079196       43.61       NaN   284621          99487362.0
# 6082704       48.19       NaN   468552          46916395.0
# 6089720       20.45       NaN   272910          26576661.0
# 6093228       20.32       NaN   211487          48985000.0
#
# [1670 rows x 11 columns]

# %%
# Do the same in the opposite direction. 
Income_Data_2018 = Income_Data_2018[Income_Data_2018['Ticker'].isin(stock_prices_2018['Ticker'])]
Income_Data_2018
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9          A     45846      USD         2017            FY  2017-10-31
# 14        AA    367153      USD         2017            FY  2017-12-31
# 26       AAL     68568      USD         2017            FY  2017-12-31
# 33      AAMC    847094      USD         2017            FY  2017-12-31
# 52      AAOI    671827      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 17068   ZNGA    418866      USD         2017            FY  2017-12-31
# 17079    ZTS    378251      USD         2017            FY  2017-12-31
# 17088   ZUMZ     45730      USD         2017            FY  2018-02-28
# 17104   ZYNE    901704      USD         2017            FY  2017-12-31
# 17114   ZYXI    171401      USD         2017            FY  2017-12-31
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 9       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 14      2018-02-26    2018-02-26     184000000.0       187000000.0  ...
# 26      2018-02-21    2018-02-21     489164000.0       491692000.0  ...
# 33      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 52      2018-02-28    2018-02-28      19097355.0        20139105.0  ...
# ...            ...           ...             ...               ...  ...
# 17068   2018-02-20    2019-02-28     869067000.0       897165000.0  ...
# 17079   2018-02-15    2018-02-15     489918000.0       493161000.0  ...
# 17088   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 17104   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 17114   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                      -38000000.0            -57000000.0
# 14                     -46000000.0           -104000000.0
# 26                    -974000000.0           -959000000.0
# 33                       1086000.0                    0.0
# 52                      -2425000.0              -637000.0
# ...                            ...                    ...
# 17068                   11859000.0              5309000.0
# 17079                 -181000000.0           -175000000.0
# 17088                    -357000.0               495000.0
# 17104                     810705.0               519554.0
# 17114                   -1450000.0             -1450000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 9                       803000000                      NaN
# 14                     1468000000             -309000000.0
# 26                     3084000000                      NaN
# 33                       -6261000                      0.0
# 52                       84526000                      NaN
# ...                           ...                      ...
# 17068                    37583000                      NaN
# 17079                  1544000000              -19000000.0
# 17088                    48403000                      NaN
# 17104                   -32012304                      0.0
# 17114                     7494000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 9                 803000000                      -1.190000e+08
# 14               1159000000                      -6.000000e+08
# 26               3084000000                      -1.165000e+09
# 33                 -6261000                      -7.080000e+05
# 52                 84526000                      -1.057500e+07
# ...                     ...                                ...
# 17068              37583000                      -1.094400e+07
# 17079            1525000000                      -6.630000e+08
# 17088              48403000                      -2.160100e+07
# 17104             -32012304                       0.000000e+00
# 17114               7494000                      -1.290000e+05
#
#        Income (Loss) from Continuing Operations  \
# 9                                     684000000
# 14                                    559000000
# 26                                   1919000000
# 33                                     -6969000
# 52                                     73951000
# ...                                         ...
# 17068                                  26639000
# 17079                                 862000000
# 17088                                  26802000
# 17104                                 -32012304
# 17114                                   7365000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                   NaN   684000000            684000000
# 14                                  NaN   217000000            217000000
# 26                                  NaN  1919000000           1919000000
# 33                                  NaN    -6969000             -7175000
# 52                                  NaN    73951000             73951000
# ...                                 ...         ...                  ...
# 17068                               NaN    26639000             26639000
# 17079                               NaN   864000000            864000000
# 17088                               NaN    26802000             26802000
# 17104                               NaN   -32012304            -32012304
# 17114                               NaN     7365000              7365000
#
# [1670 rows x 28 columns]

# %%
# We have lost some rows in our dataframes in keeping only common stock tickers. Sometimes we loose things, such is life.
# Arrange both income and stock price dataframes alphabetically so the rows correspond.
# Create a new dataframe called stock_data_2018 as a copy of Income_Data_2018 (we will be adding some columns soon)
# Create a market cap column in stock_data_2018 by multiplying the open price with the number of shares outstanding,
# use .values to do the multiplication.

stock_prices_2018 = stock_prices_2018.sort_values(by=['Ticker'])
Income_Data_2018 = Income_Data_2018.sort_values(by=['Ticker'])

# Make the stock_data DataFrame from the Income Data and add a Market Cap series.
stock_data_2018 = Income_Data_2018
stock_data_2018['Market Cap'] = Income_Data_2018['Shares (Diluted)'].values * stock_prices_2018['Open'].values

# %%
# Take a look at the distribution of Market Caps in the stock market with a histogram.
# use a large number of hisogram bins and a log scale, this will enable you to view the data better.
# You will see that there are many at the low end, and very few super large corporations in America

stock_data_2018['Market Cap'].hist(bins=100, log=True)
# Try to format this graph yourself with title, axis labels and so on.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Using market cap, make a price/earnings Series in the Stock_Data DataFrame

# %%
# Define a new column for price/earnings
# and view the histogram for it

stock_data_2018['Price/Earnings'] = stock_data_2018['Market Cap']/stock_data_2018['Net Income']
stock_data_2018['Price/Earnings'].hist(bins=100, log=True)
# Notice that there are values all over the place 
# some p/e ratios are above 10,000! and there are many below 0 (they don't earn eanything!)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Filter your stock data
# Filter your stock data for a reasonable range of price/earnings ratios of companies you might invest in, say from 5 to 50, and look at the histogram of the resulting companies.
# You may need to use a boolean list with some logic to do so.

# %%
# Make the same histogram as before for p/e but this time after a filter by p/e above 5 and below 50.
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (stock_data_2018['Price/Earnings'] <= 50))]['Price/Earnings'].hist()
# Out:
# <AxesSubplot:>

# %%
#View a histogram of a different column, say market cap, but with the same p/e filter
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (stock_data_2018['Price/Earnings'] <= 50))]['Market Cap'].hist(log=True)
# Out:
# <AxesSubplot:>

# %%
stock_data_2018.keys()
# Out:
# Index(['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period',
#        'Report Date', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income', 'Net Income (Common)',
#        'Market Cap', 'Price/Earnings'],
#       dtype='object')

# %%
# You can also plot scatter plots with Pandas, here is an example scatter plot of Net Income vs. Market Cap.
# Larger companies earn more.
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & \
                 (stock_data_2018['Price/Earnings'] <= 50))]\
                .plot.scatter(x = 'Market Cap', y = 'Net Income')
# Out:
# <AxesSubplot:xlabel='Market Cap', ylabel='Net Income'>

# %% [markdown]
# End of Exercise 6. With the tools you have you are now able to use Pandas to filter through fundamental stock data. There are a myriad of ratios and analyses that may be carried out to filter through stocks to find good investments. In the next chapter we will learn some basics of Machine Learning to try and sift through data and find useful infomation.

# %% [markdown]
# # Pandas Data Reader

# %%
import pandas as pd
import pandas_datareader.data as pdr
from matplotlib import pyplot as plt

start = pd.to_datetime('2019-05-01')
end = pd.to_datetime('2020-05-01')
tickerData = pdr.DataReader('SPY', 'yahoo', start, end);

plt.plot(tickerData['Open']);
plt.grid()
plt.xlabel('Date')
plt.ylabel('SPY value')
# Out:
# Text(0, 0.5, 'SPY value')

# %%
tickerData
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-05-01  294.950012  291.799988  294.720001  291.809998   71671900.0
# 2019-05-02  292.700012  289.519989  291.679993  291.179993   65030200.0
# 2019-05-03  294.339996  291.299988  292.820007  294.029999   56543700.0
# 2019-05-06  293.309998  288.899994  289.250000  292.820007  107198100.0
# 2019-05-07  290.809998  285.809998  290.149994  287.929993  144729900.0
# ...                ...         ...         ...         ...          ...
# 2020-04-27  288.269989  284.619995  285.119995  287.049988   77896600.0
# 2020-04-28  291.399994  285.399994  291.019989  285.730011  105270000.0
# 2020-04-29  294.880005  290.410004  291.529999  293.209991  118745600.0
# 2020-04-30  293.320007  288.589996  291.709991  290.480011  122901700.0
# 2020-05-01  290.660004  281.519989  285.309998  282.790009  125180000.0
#
#              Adj Close
# Date
# 2019-05-01  282.375183
# 2019-05-02  281.765503
# 2019-05-03  284.523407
# 2019-05-06  283.352539
# 2019-05-07  278.620605
# ...                ...
# 2020-04-27  283.444672
# 2020-04-28  282.141235
# 2020-04-29  289.527283
# 2020-04-30  286.831604
# 2020-05-01  279.238159
#
# [254 rows x 6 columns]

# %% [markdown]
# ### iloc and loc

# %%
# .iloc[] selects rows like a list

# %%
tickerData.iloc[-5:] #last 5
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-04-27  288.269989  284.619995  285.119995  287.049988   77896600.0
# 2020-04-28  291.399994  285.399994  291.019989  285.730011  105270000.0
# 2020-04-29  294.880005  290.410004  291.529999  293.209991  118745600.0
# 2020-04-30  293.320007  288.589996  291.709991  290.480011  122901700.0
# 2020-05-01  290.660004  281.519989  285.309998  282.790009  125180000.0
#
#              Adj Close
# Date
# 2020-04-27  283.444672
# 2020-04-28  282.141235
# 2020-04-29  289.527283
# 2020-04-30  286.831604
# 2020-05-01  279.238159

# %%
tickerData.iloc[:5] #first 5
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-05-01  294.950012  291.799988  294.720001  291.809998   71671900.0
# 2019-05-02  292.700012  289.519989  291.679993  291.179993   65030200.0
# 2019-05-03  294.339996  291.299988  292.820007  294.029999   56543700.0
# 2019-05-06  293.309998  288.899994  289.250000  292.820007  107198100.0
# 2019-05-07  290.809998  285.809998  290.149994  287.929993  144729900.0
#
#              Adj Close
# Date
# 2019-05-01  282.375183
# 2019-05-02  281.765503
# 2019-05-03  284.523407
# 2019-05-06  283.352539
# 2019-05-07  278.620605

# %%
tickerData.iloc[207] # row 207
# Out:
# High         3.181100e+02
# Low          3.107000e+02
# Open         3.141800e+02
# Close        3.115000e+02
# Volume       1.947738e+08
# Adj Close    3.057895e+02
# Name: 2020-02-26 00:00:00, dtype: float64

# %%
# .loc[] selects rows using the index. With Timeseries data like this, the index is a date, not a number.
tickerData.loc['2019-05-01']
# Out:
# High         2.949500e+02
# Low          2.918000e+02
# Open         2.947200e+02
# Close        2.918100e+02
# Volume       7.167190e+07
# Adj Close    2.823752e+02
# Name: 2019-05-01 00:00:00, dtype: float64

# %%
tickerData.loc[tickerData.index>'2020-01-01']['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
